# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('../DATA/titanic_train.csv')
df=train.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 2.Creating DataFrame

# %%
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
student_dict={'Name':['A','B','C'], 'Age':[24,18,17], 'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# 3.Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 4.Modify/Add new column(s)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
df['Third&Men']=df.apply(lambda row: int(row['Pclass']==3 and row['Sex']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men
# 0                              Mr. Owen Harris          1
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2                                  Miss. Laina          0
# 3           Mrs. Jacques Heath (Lily May Peel)          0
# 4                            Mr. William Henry          1

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# 5.Deleting columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df=df.drop(['PassengerId'],axis=1)
df.head()
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# 6.Renaming columns

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# 7.i Slicing DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_third_class=df[df['Pclass']==3].reset_index(drop=True)
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 2         0       3        Allen, Mr. William Henry      0  35.000000      0
# 3         0       3                Moran, Mr. James      0  29.699118      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  Third&Men  Age_group
# 0         Mr. Owen Harris          1          2
# 1             Miss. Laina          0          2
# 2       Mr. William Henry          1          2
# 3               Mr. James          1          2
# 4   Master. Gosta Leonard          1          1

# %%
df_aged=df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                                     Name  Third&Men  Age_group
# 275             Miss. Kornelia Theodosia          0          4
# 483                        Mrs. (Hedwig)          0          4
# 829   Mrs. George Nelson (Martha Evelyn)          0          4

# %%
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Third&Men  Age_group
# 0         0       3  22.0      1      0   7.2500          1          2
# 1         1       1  38.0      1      0  71.2833          0          2
# 2         1       3  26.0      0      0   7.9250          0          2
# 3         1       1  35.0      1      0  53.1000          0          2
# 4         0       3  35.0      0      0   8.0500          1          2

# %%
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                         Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %% [markdown]
# 7.ii Slicing using iloc and loc

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub2=df.iloc[:250,[1,8]]
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub3=df.loc[:500,:]

# %%
df_sub4=df.loc[(df['Age']>50),['Gender','Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %% [markdown]
# 8.Adding a row

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
row=dict({'Age':24, 'Full Name':'Peter','Survided':'Y'})
df=df.append(row,ignore_index=True)
df.tail()
# Out:
# /var/folders/jk/1cws__yn4bbfzktv83sdj85w0000gn/T/ipykernel_9285/4122487927.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(row,ignore_index=True)
#      Survived  Pclass                                 Full Name Gender  \
# 887       1.0     1.0              Graham, Miss. Margaret Edith      1
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889       1.0     1.0                     Behr, Mr. Karl Howell      0
# 890       0.0     3.0                       Dooley, Mr. Patrick      0
# 891       NaN     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  Third&Men  Age_group Survided
# 887             Miss. Margaret Edith        0.0        2.0      NaN
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0      NaN
# 889                  Mr. Karl Howell        0.0        2.0      NaN
# 890                      Mr. Patrick        1.0        2.0      NaN
# 891                              NaN        NaN        NaN        Y

# %%
df.loc[len(df.index)]=row
df.tail()
# Out:
#      Survived  Pclass                                 Full Name Gender  \
# 888       0.0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889       1.0     1.0                     Behr, Mr. Karl Howell      0
# 890       0.0     3.0                       Dooley, Mr. Patrick      0
# 891       NaN     NaN                                     Peter    NaN
# 892       NaN     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
# 892  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  Third&Men  Age_group Survided
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0      NaN
# 889                  Mr. Karl Howell        0.0        2.0      NaN
# 890                      Mr. Patrick        1.0        2.0      NaN
# 891                              NaN        NaN        NaN        Y
# 892                              NaN        NaN        NaN        Y

# %% [markdown]
# 9.Dropping row(s)

# %%
df=df.drop(df.index[-1],axis=0)
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris      0
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2       1.0     3.0                             Heikkinen, Miss. Laina      1
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4       0.0     3.0                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0    1.0    0.0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0    1.0    0.0            113803  53.1000  C123        S   Futrelle
# 4  35.0    0.0    0.0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group Survided
# 0                              Mr. Owen Harris        1.0        2.0      NaN
# 1   Mrs. John Bradley (Florence Briggs Thayer)        0.0        2.0      NaN
# 2                                  Miss. Laina        0.0        2.0      NaN
# 3           Mrs. Jacques Heath (Lily May Peel)        0.0        2.0      NaN
# 4                            Mr. William Henry        1.0        2.0      NaN

# %% [markdown]
# 10.Sorting

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris      0
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2       1.0     3.0                             Heikkinen, Miss. Laina      1
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4       0.0     3.0                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0    1.0    0.0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0    1.0    0.0            113803  53.1000  C123        S   Futrelle
# 4  35.0    0.0    0.0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third&Men  Age_group Survided
# 0                              Mr. Owen Harris        1.0        2.0      NaN
# 1   Mrs. John Bradley (Florence Briggs Thayer)        0.0        2.0      NaN
# 2                                  Miss. Laina        0.0        2.0      NaN
# 3           Mrs. Jacques Heath (Lily May Peel)        0.0        2.0      NaN
# 4                            Mr. William Henry        1.0        2.0      NaN

# %%
df=df.sort_values(by=['Age'],ascending=False)
df.head()
# Out:
#      Survived  Pclass                             Full Name Gender   Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851       0.0     3.0                   Svensson, Mr. Johan      0  74.0
# 96        0.0     1.0             Goldschmidt, Mr. George B      0  71.0
# 493       0.0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 116       0.0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  Third&Men  Age_group Survided
# 630   Mr. Algernon Henry Wilson        0.0        4.0      NaN
# 851                   Mr. Johan        1.0        4.0      NaN
# 96                 Mr. George B        0.0        4.0      NaN
# 493                   Mr. Ramon        0.0        4.0      NaN
# 116                 Mr. Patrick        1.0        4.0      NaN

# %% [markdown]
# 12.Groupby

# %%
df.head()
# Out:
#      Survived  Pclass                             Full Name Gender   Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851       0.0     3.0                   Svensson, Mr. Johan      0  74.0
# 96        0.0     1.0             Goldschmidt, Mr. George B      0  71.0
# 493       0.0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 116       0.0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  Third&Men  Age_group Survided
# 630   Mr. Algernon Henry Wilson        0.0        4.0      NaN
# 851                   Mr. Johan        1.0        4.0      NaN
# 96                 Mr. George B        0.0        4.0      NaN
# 493                   Mr. Ramon        0.0        4.0      NaN
# 116                 Mr. Patrick        1.0        4.0      NaN

# %%
groups=df.groupby(['Pclass'])
#groups.groups
groups.get_group(1)
# Out:
#      Survived  Pclass                             Full Name Gender    Age  \
# 630       1.0     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.00
# 96        0.0     1.0             Goldschmidt, Mr. George B      0  71.00
# 493       0.0     1.0               Artagaveytia, Mr. Ramon      0  71.00
# 745       0.0     1.0          Crosby, Capt. Edward Gifford      0  70.00
# 54        0.0     1.0        Ostby, Mr. Engelhart Cornelius      0  65.00
# ..        ...     ...                                   ...    ...    ...
# 435       1.0     1.0             Carter, Miss. Lucile Polk      1  14.00
# 802       1.0     1.0   Carter, Master. William Thornton II      0  11.00
# 445       1.0     1.0             Dodge, Master. Washington      0   4.00
# 297       0.0     1.0          Allison, Miss. Helen Loraine      1   2.00
# 305       1.0     1.0        Allison, Master. Hudson Trevor      0   0.92
#
#      SibSp  Parch     Ticket      Fare    Cabin Embarked       Surname  \
# 630    0.0    0.0      27042   30.0000      A23        S     Barkworth
# 96     0.0    0.0   PC 17754   34.6542       A5        C   Goldschmidt
# 493    0.0    0.0   PC 17609   49.5042      NaN        C  Artagaveytia
# 745    1.0    1.0  WE/P 5735   71.0000      B22        S        Crosby
# 54     0.0    1.0     113509   61.9792      B30        C         Ostby
# ..     ...    ...        ...       ...      ...      ...           ...
# 435    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 802    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 445    0.0    2.0      33638   81.8583      A34        S         Dodge
# 297    1.0    2.0     113781  151.5500  C22 C26        S       Allison
# 305    1.0    2.0     113781  151.5500  C22 C26        S       Allison
#
#                              Name  Third&Men  Age_group Survided
# 630     Mr. Algernon Henry Wilson        0.0        4.0      NaN
# 96                   Mr. George B        0.0        4.0      NaN
# 493                     Mr. Ramon        0.0        4.0      NaN
# 745          Capt. Edward Gifford        0.0        4.0      NaN
# 54        Mr. Engelhart Cornelius        0.0        4.0      NaN
# ..                            ...        ...        ...      ...
# 435             Miss. Lucile Polk        0.0        1.0      NaN
# 802   Master. William Thornton II        0.0        1.0      NaN
# 445            Master. Washington        0.0        1.0      NaN
# 297           Miss. Helen Loraine        0.0        1.0      NaN
# 305         Master. Hudson Trevor        0.0        1.0      NaN
#
# [216 rows x 16 columns]

# %%
df_grp1=df.groupby(['Pclass'])

# %%
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %%
df_grp1['Age'].min()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    216
# 2.0    184
# 3.0    491
# Name: Age, dtype: int64

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_grp2=df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)})
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
df_grp3=df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          0.92
# 2          0.67
# 3          0.42

# %%
df_grp4=df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem), Hewlett, ...
# 3       Braund, Mr. Owen Harris, Heikkinen, Miss. Lain...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_grp5=df.groupby(['Pclass']).agg({'Age':['max', 'min']})
df_grp5.head()
# Out:
#          Age
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %%
df.to_csv('../DATA/titanic_train_modified.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_survived=df[(df['Sex']=='female') & (df['Survived']==1)]

# %%
df_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]

# %%
df[df.Fare == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 806          807         0       1            Andrews, Mr. Thomas Jr  male
# 815          816         0       1                  Fry, Mr. Richard  male
# 822          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  36.0      0      0    LINE   0.0   NaN        S
# 263  40.0      0      0  112059   0.0   B94        S
# 271  25.0      0      0    LINE   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S
# 413   NaN      0      0  239853   0.0   NaN        S
# 466   NaN      0      0  239853   0.0   NaN        S
# 481   NaN      0      0  239854   0.0   NaN        S
# 597  49.0      0      0    LINE   0.0   NaN        S
# 633   NaN      0      0  112052   0.0   NaN        S
# 674   NaN      0      0  239856   0.0   NaN        S
# 732   NaN      0      0  239855   0.0   NaN        S
# 806  39.0      0      0  112050   0.0   A36        S
# 815   NaN      0      0  112058   0.0  B102        S
# 822  38.0      0      0   19972   0.0   NaN        S

# %%
df[df.Survived ==1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df[df.Pclass == 1].Fare.mean()
# Out:
# 84.15468749999992

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
